# %% [markdown]
# <a href="https://colab.research.google.com/github/DeivisDervinis/RandomDataSetGeneration/blob/main/GenerateRandomDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 ffmpeg
# !pip install PyAudio
# !pip install pydub
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libasound2-dev is already the newest version (1.1.3-5ubuntu0.5).
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# Suggested packages:
#   portaudio19-doc
# The following NEW packages will be installed:
#   libportaudio2 libportaudiocpp0 portaudio19-dev
# 0 upgraded, 3 newly installed, 0 to remove and 30 not upgraded.
# Need to get 184 kB of archives.
# After this operation, 891 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudio2 amd64 19.6.0-1 [64.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudiocpp0 amd64 19.6.0-1 [15.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 portaudio19-dev amd64 19.6.0-1 [104 kB]
# Fetched 184 kB in 1s (349 kB/s)
# Selecting previously unselected package libportaudio2:amd64.
# ...

# %%
# !mkdir data
# !mkdir working

# !wget http://github.com/DeivisDervinis/RandomDataSetGeneration/raw/main/data/data.zip -O data/data.zip
# Out:
# --2021-03-28 00:25:16--  http://github.com/DeivisDervinis/RandomDataSetGeneration/raw/main/data/data.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/DeivisDervinis/RandomDataSetGeneration/raw/main/data/data.zip [following]
# --2021-03-28 00:25:16--  https://github.com/DeivisDervinis/RandomDataSetGeneration/raw/main/data/data.zip
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/DeivisDervinis/RandomDataSetGeneration/main/data/data.zip [following]
# --2021-03-28 00:25:16--  https://media.githubusercontent.com/media/DeivisDervinis/RandomDataSetGeneration/main/data/data.zip
# ...

# %%
# !unzip data/data.zip -d data/
# Out:
# Archive:  data/data.zip
#   inflating: data/female1_assertive_13a_2.wav
#   inflating: data/female1_assertive_13b_1.wav
#   inflating: data/female1_assertive_13b_2.wav
#   inflating: data/female1_assertive_14a_1.wav
#   inflating: data/female1_assertive_14a_2.wav
#   inflating: data/female1_assertive_14b_1.wav
#   inflating: data/female1_assertive_14b_2.wav
#   inflating: data/female1_assertive_15a_1.wav
#   inflating: data/female1_assertive_15a_2.wav
#   inflating: data/female1_assertive_15b_1.wav
#   inflating: data/female1_assertive_15b_2.wav
#   inflating: data/female1_concerned_1a_1.wav
#   inflating: data/female1_concerned_1a_2.wav
#   inflating: data/female1_concerned_1b_1.wav
#   inflating: data/female1_concerned_1b_2.wav
#   inflating: data/female1_concerned_2a_1.wav
#   inflating: data/female1_concerned_2a_2.wav
#   inflating: data/female1_concerned_2b_1.wav
#   inflating: data/female1_concerned_2b_2.wav
#   inflating: data/female1_concerned_3a_1.wav
# ...

# %%
# !rm data/data.zip

# %%
import glob
files = glob.glob("data/" + '/*.wav')

# %%
import random
from pydub import AudioSegment
import numpy as np

randListIndex = []
# Generate a list of random numbers
randListIndex = random.sample(range(0,2400 + 1), 2400)


#randListIndex[5]
files[1333]
# Out:
# 'data/male1_anxious_10a_1.wav'

# %%
listOfFrags = []
listOfFinalFrags = []

for item in range(0, len(files)):
  for frag in range(0, 10):
    aud_frag = AudioSegment.from_wav(files[randListIndex[frag]])

    listOfFrags.append(aud_frag)
    print(listOfFrags)
  #listOfFinalFrags.append(listOfFrags)
  #listOfFrags.clear()

  #aud_final = aud_one + aud_two + aud_three + aud_four + aud_five + aud_six + aud_seven + aud_eight + aud_nine
  # remove the files that were used

  #for counter in range(0, 10):
    #print(randListIndex[counter])
    #randListIndex.remove(randListIndex[counter])

listOfFinalFrags
# Out:
# ...
# [<pydub.audio_segment.AudioSegment object at 0x7fb40374d210>, <pydub.audio_segment.AudioSegment object at 0x7fb40374dc10>]
# [<pydub.audio_segment.AudioSegment object at 0x7fb40374d210>, <pydub.audio_segment.AudioSegment object at 0x7fb40374dc10>, <pydub.audio_segment.AudioSegment object at 0x7fb40374d8d0>]
# [<pydub.audio_segment.AudioSegment object at 0x7fb40374d210>, <pydub.audio_segment.AudioSegment object at 0x7fb40374dc10>, <pydub.audio_segment.AudioSegment object at 0x7fb40374d8d0>, <pydub.audio_segment.AudioSegment object at 0x7fb40374d790>]
# [<pydub.audio_segment.AudioSegment object at 0x7fb40374d210>, <pydub.audio_segment.AudioSegment object at 0x7fb40374dc10>, <pydub.audio_segment.AudioSegment object at 0x7fb40374d8d0>, <pydub.audio_segment.AudioSegment object at 0x7fb40374d790>, <pydub.audio_segment.AudioSegment object at 0x7fb40374d690>]
# ...

# %%
listOfFinalFrags
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-a63cde243cfd> in <module>()
# ----> 1 listOfFinalFrags
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# ...
